# %%
import pandas as pd


# !which python
# !where python
# Out:
# 'which' is not recognized as an internal or external command,
# operable program or batch file.
# c:\Repo\recommendersystems\RS\Scripts\python.exe
# C:\Users\willi\AppData\Local\Programs\Python\Python312\python.exe
# C:\Users\willi\AppData\Local\Microsoft\WindowsApps\python.exe

# %%
danish_articles = pd.read_parquet('../data/ebnerd_large/articles.parquet', engine='pyarrow')
danish_behaviors = pd.read_parquet('../data/ebnerd_large/train/behaviors.parquet', engine='pyarrow')
danish_history = pd.read_parquet('../data/ebnerd_large/train/history.parquet', engine='pyarrow')
mind_articles = pd.read_csv("../data/MINDlarge_train/news.tsv", sep="\t")

# %%
mind_articles["lifestyle"].unique()
mind_articles["lifestyleroyals"].unique()
# Out:
#          N88753 lifestyle           lifestyleroyals  \
# 0        N45436      news  newsscienceandtechnology
# 1        N23144    health                weightloss
# 2        N86255    health                   medical
# 3        N93187      news                 newsworld
# 4        N75236    health                    voices
# ...         ...       ...                       ...
# 101521  N115249    sports               more_sports
# 101522   N64337   finance       finance-real-estate
# 101523  N100102    sports                soccer_epl
# 101524   N74617     autos               autossports
# 101525   N56840    sports               more_sports
#
#        The Brands Queen Elizabeth, Prince Charles, and Prince Philip Swear By  \
# 0         Walmart Slashes Prices on Last-Generation iPads
# 1                           50 Worst Habits For Belly Fat
# 2       Dispose of unwanted prescription drugs during ...
# 3       The Cost of Trump's Aid Freeze in the Trenches...
# ...

# %%
danish_articles
# danish_behaviors
# danish_history
# Out:
#         article_id                                              title  \
# 0          3000022                     Hanks beskyldt for mishandling
# 1          3000063                    Bostrups aske spredt i Furesøen
# 2          3000613                Jesper Olsen ramt af hjerneblødning
# 3          3000700                           Madonna topløs med heste
# 4          3000840                            Otto Brandenburg er død
# ...            ...                                                ...
# 125536     9803505                Flyvende Antonsen knuser topspiller
# 125537     9803510  Nedschroef Langeskov udbetalte udbytte på toci...
# 125538     9803525   Dansk skuespiller: - Jeg nægtede, at jeg var syg
# 125539     9803560        Så slemt er det: 14.000 huse er oversvømmet
# 125540     9803607        Aktion mod svindlere: Seks personer anholdt
#
#                                                  subtitle  last_modified_time  \
# ...
